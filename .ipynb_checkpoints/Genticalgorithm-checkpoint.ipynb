# %%
pip install geneticalgorithm
# Out:
# Collecting geneticalgorithm
#   Downloading geneticalgorithm-1.0.2-py3-none-any.whl.metadata (25 kB)
# Collecting func-timeout (from geneticalgorithm)
#   Downloading func_timeout-4.3.5.tar.gz (44 kB)
#      ---------------------------------------- 0.0/44.3 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/44.3 kB ? eta -:--:--
#      -------------------------- ----------- 30.7/44.3 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 44.3/44.3 kB 362.0 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\mehta\appdata\local\programs\python\python312\lib\site-packages (from geneticalgorithm) (1.26.4)
# Downloading geneticalgorithm-1.0.2-py3-none-any.whl (16 kB)
# Building wheels for collected packages: func-timeout
#   Building wheel for func-timeout (pyproject.toml): started
#   Building wheel for func-timeout (pyproject.toml): finished with status 'done'
#   Created wheel for func-timeout: filename=func_timeout-4.3.5-py3-none-any.whl size=15108 sha256=3039f1a77c7d6712bfd2dae4b5860a90d7a0a8ba56401e322ce491110675606f
#   Stored in directory: c:\users\mehta\appdata\local\pip\cache\wheels\ed\94\4a\9ccd71f7284a92e4137b7dd0ce8540c40ea7c2689251504a49
# Successfully built func-timeout
# Installing collected packages: func-timeout, geneticalgorithm
# Successfully installed func-timeout-4.3.5 geneticalgorithm-1.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from geneticalgorithm import geneticalgorithm as ga
def f(X):
    return np.sum(X)
varbound=np.array([[0,10]]*3)
model=ga(function=f,dimension=3,variable_type='real',variable_boundaries=varbound)
model.run()
# Out:
#  The best solution found:
#  [0.00583143 0.00148262 0.00448758]
#
#  Objective function:
#  0.011801628349067395

# %%
import numpy as np
from geneticalgorithm import geneticalgorithm as ga
def f(X):
    return np.sum(X)
varbound=np.array([[0,10]]*3)
model=ga(function=f,dimension=3,variable_type='int',variable_boundaries=varbound)
model.run()
# Out:
#  The best solution found:
#  [0. 0. 0.]
#
#  Objective function:
#  0.0

# %%
algorithm_param= {'max_num_iteration':3000,\ 
                  'population_size': 100,\ 
                  'crossover_probability' : 0.5,\
                  'mutation_probability':0.1 .\ 
                  'crossover_type': 'uniform'\ 
                  'max_iteration_without_improv': None}
# Out:
#   Cell In[13], line 1
#     algorithm_param= {'max_num_iteration':3000\
#                                                ^
# SyntaxError: unexpected character after line continuation character
